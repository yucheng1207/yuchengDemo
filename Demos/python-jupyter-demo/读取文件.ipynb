# %%
def readFile(url):
    f = open(url, 'r', encoding='utf-8')
    content = f.read()
    # print(content)
    f.close()
    return content

# %%
import re
def isExistInFile(newFileUrl, outputUrl):
    fdest = open(newFileUrl, 'r', encoding='utf-8')
    newContent = 'unknow'
    for content in fdest.readlines():
        pattern = re.compile(r'\d{1,3}\.')
        res = pattern.match(content.strip()) # 问题在第一行不能匹配？？？
        # print(bool(re.match('\d{1,3}\.', '123.')))
        # print(res and res.group())
        # print(bool(re.search('\d{1,3}\.', '1123.')))
        if (res != None):
            newContent = content # 获取问题行
            # break # 注释掉break获取最后一行问题
    fdest.close()
    
    if (newContent == 'unknow'):
        print('文件内容出错')
        return 'error'
    
    # print('newContent', newContent)
    f = open(outputUrl, 'r', encoding='utf-8')
    isExist = False
    # print(newContent, f.readlines())
    for line in f.readlines():                          #依次读取每行
        if newContent in line:
            print('已存在', newContent)
            isExist = True
            break
    f.close()
    if isExist:
        return 'exist'
    else:
        return 'not exist'

# %%
def isQuestionStartLine(line):
    return bool(re.match('\d{1,3}\.', line))

# %%
def isQuestionEndLine(line):
    return bool(re.match('正确答案', line))

# %%
def isEmptyLine(line):
    return bool(re.match('\n', line))

# %%
def getQuestion(url):
    f = open(url, 'r+', encoding='utf-8')
    retrieving = False
    result = ''
    firstQ = ''
    lastQ = ''
    
#     line = f.readline()
#     print ("读取的数据为: %s" % (line))
#     f.seek(0, 0)
#     line = f.readline()
#     print ("读取的数据为: %s" % (line))

    for line in f.readlines():                          #依次读取每行
        if isQuestionStartLine(line):
            if firstQ == '':
                firstQ = line
            lastQ = line
            retrieving = True
        if isQuestionEndLine(line):
            retrieving = False

        if retrieving == True:
            result = result + line
        
        if retrieving == False:
            result = result + '\n'
        
    
    print('第一行问题：', firstQ)
    print('最后一行问题：', lastQ)

    f.close()

    return result

# %%
def addQuestionToFile(content, destUrl):
    fo = open(destUrl, "a+") # 打开一个文件用于追加读写
    str = content
    # 在文件末尾写入一行
    fo.seek(0, 2)
    line = fo.write( str )
    # 关闭文件
    fo.close()

# %%
def writeFile(content, destUrl):
    fo = open(destUrl, "w+") # 打开一个文件用于读写
    # 在文件末尾写入一行
    fo.seek(0, 0)
    line = fo.write( content )
    # 关闭文件
    fo.close()

# %%
def addEmptyLine(destUrl):
    # 打开文件
    fo = open(destUrl, "r+")
    print ("文件名为: ", fo.name)

    line = fo.readline()
    print ("读取的数据为: %s" % (line))

    # 重新设置文件读取指针到开头
    fo.seek(0, 0)
    line = fo.readline()
    fo.seek(0, 0)
    # fo.writelines(['\n'])
    # line = fo.write('555\n')
    print ("读取的数据为: %s" % (line))


    # 关闭文件
    fo.close()

# %%
def removeBlankLines(url, maxBlankLines): # 最多保留多少空行
    f = open(url, 'r+', encoding='utf-8')
    count = 0
    prevLineIsEmpty = False
    result = ''
    for line in f.readlines():                          #依次读取每行
        if isEmptyLine(line):
            if prevLineIsEmpty == False:
                result = result + '\n'
            if prevLineIsEmpty == True:
                count = count + 1
            prevLineIsEmpty = True
        else:
            count = 0
            prevLineIsEmpty = False
            result = result + line

    f.close()
    return result

# %%
originalUrl = '/Users/apple/zyc/zhl/旅游管理题目/4/4-txt版本/0_13_68.txt'
outputUrl = '/Users/apple/zyc/zhl/旅游管理题目/4/output/4-result.txt'
# addEmptyLine(originalUrl)
isExist = isExistInFile(originalUrl, outputUrl)
# questions1 = getQuestion(originalUrl)
# print('questions1', questions1)
# addQuestionToFile(questions1, outputUrl)
# reault = readFile(outputUrl)
# print(reault)
result1 = removeBlankLines(outputUrl, 1)
print('result', result1)
print('isExist', isExist)
if (isExist == 'not exist'):
    questions = getQuestion(originalUrl)
    addQuestionToFile(questions, outputUrl)
    reault = readFile(outputUrl)
    print(reault)

# 去掉空白行
# data = removeBlankLines(outputUrl, 1)
# writeFile(data, outputUrl)
# Out:
# 已存在 165.中国、哈萨克斯坦和吉尔吉斯斯坦三国联合申遗的世界遗产“丝绸之路：长安一天山廊道
#
# result
# 1.《旅游法》的立法目的是为了保障旅游者和旅游经营者的合法权益，完善国家法律规范
# 体系，保护和合理利用旅游资源，促进旅游业持续健康发展。()
#
# 2.合同依法成立以后，对双方当事人都有法律约束力，双方必须严格按照合同约定履行自己
# 的义务，任何一方都不得变更依法成立的合同。(
#
# 3.《民法典》规定，合同解除的条件包括约定解除和法定解除。()
#
# 4.侵权损害赔偿仅指行为人因侵权而造成的他人财产、人身损害，依法应承担的以给付金钱
# 或实物为内容的民事责任方式。()
#
# 5.《旅行社条例》规定，申请设立旅行社，经营国内旅游业务和入境旅游业务的，应当向县
# 级以上旅游行政管理部门提交相关文件。(
#
# 6.平台内经营者与旅游者发生旅游纠纷的，鼓励平台经营者先行赔付。()
#
# 7.《导游管理办法》规定，导游服务星级根据星级评价指标通过全国旅游监管服务信息系统
# 自动生成，并根据导游执业情况每年更新一次。(
#
# 8.《导游人员管理条例》规定，导游对旅游行政部门的行政行为不服时，导游可以申请复议，
# 也可以提请仲裁机构仲裁。()
#
# 9.根据《治安管理处罚法》规定，刻划、涂污或者以其他方式故意损坏国家保护的文物、名
# 胜古迹的，情节较重的，处警告或者500元以下罚款。(
#
# 10.某旅行社组团30人前往内地某城市旅游，其中有3名旅游者认为旅行社提供的团队餐与
# 旅游合同约定不符，并以此为由向旅行社所在地旅游主管部门]投诉该旅行社，根据《旅游
# 投诉处理办法》规定，这种投诉称为共同投诉。()
#
# 11.根据《旅游安全管理办法》规定，旅行社组织出境旅游，应当制作安全信息卡，安全信
# 息卡使用中文和英文填写。()
#
# 12.国家对野生动物实行保护优先、规范利用、严格监管的原则，鼓励开展野生动物科学研
# 究，培育公民保护野生动物的意识，促进人与自然和谐发展。()
#
# 13.2014年10月20日，党的十八届四中全会在北京召开，这是中国共产党第-次专题研究依
# 法治国问题的中央全会。()
#
# 14.中华人民共和国国徽，中间是五星照耀下的天安门，周围是谷穗和镰刀。()
#
# 15.每年9月30日为烈士纪念日，清明节当日国家在首都北京天安门广场人民英雄纪念碑前
# 举行纪念仪式，缅怀英雄烈士。()
#
# 16.“十四五”时期加强优秀文化作品创作生产传播应把提高质量作为文艺作品的生命线，
# 提高文艺原创能力。()
#
# 17.习近平总书记在庆祝中国共产党成立100周年大会上指出，一百年来，中国共产党带领中
# 国人民进行的一切奋斗、一切牺牲、一切创造，归结起来的一个主题是带领人民创造美
# 好生活。()
#
# 18.2021年6月17日，神舟12号航天员聂海胜，刘国明、景海鹏先后进入天和核心航，标志
# 着中国人首次进入自己的空间站。
#
# 19.根据我国202年第七次人口普查的数据，中国内地总人口已超15亿。()
#
# 20.2021年7月1日，习近平在庆祝中国共产党成立100周年大会上庄严宣告，经过全党全国
# 各族人民持续奋斗，我们实现了第一一个百年奋斗目标，在中华大地上全面建成了小康社会，
# 历史性地解决了绝对贫困问题。(
#
# 21.导游人员在接待游客的过程中应当具备的基本道德品质和道德情操是对待客人热情大方
# 清洁端庄。()
#
# 22.1954年，中国旅行社在北京西交民巷4号诞生。()
#
# 23.按照使用语言，我国导游人员分为中文导游人员和外语导游人员两种类型。()
#
# 24.全陪是指受国内接待旅行社委派，作为接待社的代表，在领队和地陪的配合下实施接待
# 计划，为旅行团提供全程陪同服务的工作人员。()
#
# 25.如果游览中需要登山，而少数老年旅游者或体弱旅游者不愿爬山，全陪应留下来照顾他
# 们。(
#
# 26.对方提出与原日程不符且涉及接待规格的要求，作为地陪一般应婉言拒绝，并说明我
# 方不便单方面违反合同。()
#
# 27.因职责和角色的差异，地陪与全陪导游服务的流程有明显的不同，其中各站服务只属于
# 地陪的服务流程。(
#
# 28.全自助游指个人、家庭或亲朋好友一起不使用旅行社的服务而自定行程、自主安排各项
# 旅游事宜的旅游活动。()
#
# 29.导游领队应有维护文明旅游的主动性和自觉性，关注旅游者的言行举止，在适当时机对
# 旅游者进行相应提醒、警示、劝告。()
#
# 30.迎接乘飞机来的散客，导游人员应确保在航班抵达前20分钟到达机场。()
#
# 31.美国人爱用用拇指与食指尖形成一个圆圈并手心向前表示“诅咒”的意思。()
#
# 32.分段讲解的方法适合于规模较大或范围虽然不大但功能划分较细的景区、景点。(
#
# 33.导游员遇事将维护游客的合法利益摆在首位，这体现了导游带团的服务至上原则。()
#
# 34.不轻易发表见解，一旦发表，会希望得到他人的尊重；容易交往，但他们不主动与人交往
# 是稳重型游客的特征。(
# 迅捷PDF转换器
#
# 35.对游窖提出的不合理或不可能实现的要求和意见，导游千万不能一口回绝，不能随便地
# 说出“不行”两字。()
#
# 36.常态化疫情防控期间，景点游览时提醒游客不要拥挤，有序排队，保持2米以上的安全
# 间距，提醒和要求游客佩戴口罩。()
#
# 37.护照是一-国主管机关发给本国公民出国或在国外居留的证件，证明其国籍和身份。()
#
# 38.航空公司值机柜台停止办理乘机手续的时间：国内航班一般为航班离站时间前40分钟，国
# 际航班为60分钟(
#
# 39.如果害怕上高原旅游出现高原反应，可以通过吸氧来缓解，反应强烈时提前服用抗高原
# 反应药，如红景天等。()
#
# 40.旅游团入住饭店时，如果既无领队又无团长，就须全陪导游分发房卡。()
#
# 41.《宪法》规定，根据宪法和法律，规定行政措施，制定行政法规，发布决定和命令，是
# ()的职权。
# A.全国人民代表大会B.各级人民政府C.国务院D.国家主席
#
# 42.《宪法》规定，()是我国的根本政治制度。
# A社会主义制度B人民代表大会制度C选举制度D人民民主专政制度
#
# 43.《宪法》规定，全国人民代表大会根据中华人民共和国主席的提名，决定()的人选。
# A国务院副总理B国务院总理C中华人民共和国副主席D中央军事委员会成员
#
# 44.《宪法》规定，()的人民代表大会代表由下一级的人民代表大会选举产生。
# A设区的市B不设区的市C市辖区D镇
#
# 45.《宪法》规定，最高人民检察院()地方各级人民检察院和专门人民检察院的工作。
# A.督查B.领导C.监督D.管理
#
# 46.《旅游法》共设10章112条，其中第()章规定了旅游服务合同。
# A6B5C4D3
#
# 47.景区不符合本法规定的开放条件而接待旅游者的，根据<《旅游法》的规定，以下说法正
# 确的是()。
# A由旅游行政管理部门责令停业整顿直至符合开放条件
# B罚款2万元以上20万元以下
# C情节严重的，两年内不再接受其开放申请
# D对直接负责的主管人员，处2000元以上2万元以下罚款
#
# 48.根据《旅游法》的规定，发生()情形的，组团社不能仅将余款退还旅游者。
# A旅游行程结束前，旅游者解除合同的
# B旅行社非因法定情形，单方面解除合同的
# C旅游行程开始后，旅游者解除合同的
# Ｄ旅游者从事违法或者违反社会公德的活动的，旅行社解除合同的
#
# 49.根据《旅游法》的规定，安排导游为旅游者提供服务的，应当在包价旅游合同中载明()。
# A导游星级评价信息B导游信用信息C导游服务费用D导游服务特点
#
# 50.根据《民法典》的规定，16周岁以上的未成年人，以自己的劳动收入为主要生活来源的，
# (
# )。
# A.为完全民事行为能力人
# B为限制民事行为能力人
# C.视为完全民事行为能力人
# D.为无民事行为能力人
#
# 51.《民法典》规定，当事人因防止损失扩大而支出的合理费用，由()负担。
# A采取措施的当事人B双方分担C违约方D划分责任后视具体情况
#
# 52.根据《民法典》规定，以下关于合同转让和转移的说法正确的是()。
# A合同的转让是合同内容的变更，合同的主体并不发生变化
# B债务人将合同的义务全部或者部分转移给第三人的，应当通知债权人
# C当事人方经对方同意，可以将自己在合同中的权利和义务一并移转给第三人
# Ｄ法人合并的，其权利和义务由原法人享有和承担
#
# 53.根据《民法典》的规定，宾馆、商场、餐馆、银行、机场、车站、港口、影剧院等经营
# 场所的经营者，应当对消费者尽到()义务。
# A安全检查B安全保障C安全宣讲D安全提醒
#
# 54.根据《民法典》相关规定，以下关于监护人责任的说法中正确的是()。
# A无民事行为能力人、限制民事行为能力人造成他人损害的，由监护人承担侵权责任
# B监护人尽到监护责任的，可以减轻或免除其侵权责任
# C有财产的无民事行为能力人、限制民事行为能力人造成他人损害的，从监护人财产中支付
# 赔偿费用
# D监护人支付赔偿后的不足部分，由侵权人承担
#
# 55.根据《民法典》的规定，以下对侵害他人造成人身损害的赔偿，说法正确的是()。
# A应当赔偿医疗费、护理费等合理费用
# B因误工减少的收入及利息
# C同-侵权行为造成多人死亡的，应当以相同数额确定死亡赔偿金
# D被侵权人死亡的，其亲属有权请求侵权人承担侵权责任
#
# 56.根据《旅行社条例》及《旅游法》规定，申请设立旅行社时，申请者如果租用营业用房
# 的，租期应不少于()。
# A一个月
# B三个月
# C一年
# D两年
#
# 57.《旅游法》、《旅行社条例》规定，以下关于旅行社依法诚信服务旅游者的说法中正确的
# 是(
# A发布旅游经营信息的网站，应当保证其s信息真实、准确
# B未经旅游者同意，旅行社不得在旅游合同约定之外提供其他服务
# C旅行社不得以低价组织旅游活动
# D旅行社组织、接待旅游者，一律不得指定具体购物场所
#
# 58.《旅游市场黑名单管理办法(试行)》规定，列入旅游市场黑名单所依据的行政处罚决定被
# 撤销的，文化和旅游行政部门或者文化市场综合执法机构应当自行政处罚决定被撤销之日
# 起()内，将相关市场主体和从业人员信息移出旅游市场黑名单。
# A10个工作日B20个工作日C30个工作日D30日
#
# 59.根据《旅行社服务质量赔偿标准》规定，甲旅行社未经旅游者同意，擅自将旅游者与乙
# 旅行社的旅游者拼团，并由乙旅行社组团，则甲旅行社应当向旅游者支付旅游费用总额()
# 的违约金。
# A15%B20%C25%D30%
#
# 60.在线旅游经营者违反有关规定，为以不合理低价组织的旅游活动者提供交易机会的，由
# 县级以上文化和旅游主管部门责令改正，给予警告，可并处0罚款。
# A.1万元以上3万元以下
# B.3万元以下
# C.1万元以上10万元以下
# D.1万元以下
#
# 61.下列不属于导游执业保障制度的是()。
# A导游劳动保障
# B导游专座
# C导游培训
# D导游等级评定
#
# 62.《导游管理办法》规定，我国领队管理由资格准人制改为()管理制度，旅游主管部
# 门不再对领队从业进行行政审批。
# A注册B登记C考核D备案
#
# 63.《导游人员管理条例》规定，导游人员应当不断提高()。
# A服务水平
# B职业道德修养
# C导游证等级
# D自身业务素质和职业技能
#
# 64.《旅游法》规定，导游或领队未经旅行社委派，私自承揽业务，由旅游主管部门责令改
# 正，没收违法所得，处()罚款，并暂扣或者吊销导游证。
# A500元以上5000元以下
# B2000元以上2万元以下
# C1000元以上1万元以下
# D1000元以下
#
# 65.当经营者提供商品或者服务有欺诈行为时，根据《消费者权益保护法》的规定，以下说
# 法正确的是()。
# A双方通过协商确定增加赔偿的金额
# B增加赔偿的金额为消费者购买商品的价款3倍
# C增加赔偿的金额不足1000元的，为1000
# Ｄ增加赔偿的金额为消费者接受服务的费用的10倍
#
# 66.根据《治安管理处罚法》的规定，以下属于扰乱公共秩序的行为是()。
# A强行进入航空器驾驶舱
# B在使用中的航空器上使用可能影响导航系统正常功能的工具，不听劝阻
# C非法强登机动车，影响交通工具正常行驶的
# D在铁路线路上放置障碍物或者故意向列车投掷物品
#
# 67.根据《旅游投诉管理办法》规定，旅游投诉处理机构处理旅游投诉，一般实行()制度。
# A和解B调解C仲裁D登记
#
# 68.《民事证据规定》规定，以在诉讼过程中，一方当事人对()的事实明确表示承认的，另
# 一方当事人()。
# A于己有利；无需举证证明
# B于己不利；需要举证证明
# C于己有利；需要举证证明
# D于己不利；无需举证证明
#
# 69.根据可能对旅游者造成的危害程度、紧急程度和发展态势，风险提示级别分为一级、二
# 级、三级和四级，其中()为严重级别。
# A一级B二级C三级D四级
#
# 70.依据《旅行社责任保险管理办法》的规定，旅行社投保旅行社责任保险，由旅行社与保
# 险公司协商确定责任赔偿限额，但每人人身伤亡责任限额不得低于()。
# A10万元B20万元C30万元D40万元
#
# 71.自然灾害、事故灾难或者公共卫生事件发生后，履行统--领导职责的人民政府可以采取
# 下列应急处置措施()。
# A迅速控制危险源
# B对特定区域内的燃料、燃气、电力、水的供应进行控制
# C封锁有关场所、道路，查验现场人员的身份证件
# D对特定区域内的建筑物、交通工具等进行控制
#
# 72.《旅游安全管理办法》规定，旅游突发事件发生后，旅游经营者的现场人员应当立即向
# ()报告。
# A公安机关
# B所在地旅游主管部门
# C本单位负责人
# Ｄ所在地人民政府
#
# 73.根据《出境入境管理法》，冒用他人出境入境证件出境入境的，处1000元以上()以下
# 罚款。
# A2000元Ｂ3000元C5000元D1万元
#
# 74.根据《娱乐场所管理条例》，娱乐场所可以设在下列地点()
# A居民住宅区周围
# B车站、机场等人群密集的场所
# C建筑物地下一层
# Ｄ居民楼等建筑物内
# 正确笞案C
# 题目解析
# 宝典P190，娱乐场所不得设在下列地点：(1)居民楼、博物馆、图书馆和被核定为文物保护
# 单位的建筑物内；
# (2)居民住宅区和学校、医院、机关周围；
# (3)车站、机场等人群密集的场所；(4)建筑物地下一层以下；
# (5)与危险化学品仓库毗连的区域。故本题选C。
# 75.根据《风景名胜区条例》，在风景名胜区内禁止的活动不包括()。
# A开山、开矿等破坏景观、植被和地形地貌的
# B改变水资源、水环境自然状态的活动
# C修建储存爆炸性、易燃性、放射性、毒害性、腐蚀性物品的设施
# D在景观或设施上刻画、涂污
#
# 76.根据《博物馆条例》，博物馆应当自取得登记证书之日起()内向公众开放。
# A2个月B3个月C6个月D1年
#
# 77.《国家级文化生态保护区管理办法》所称的“国家级文化生态保护区”，是指以保护()
# 为核心，对历史文化积淀丰厚、存续状态良好，具有重要价值和鲜明特色的文化形态进行整
# 体性保护，并经文化和旅游部同意设立的特定区域。
# A中华传统文化B人文环境C非物质文化遗产D自然生态环境
#
# 78.十九大报告指出，中国特色社会主义道路是实现社会主义现代化、()的必由之路。
# A实现伟大复兴的中国梦
# B实现共产主义
# C创造人民美好生活
# Ｄ构建人类命运共同体
#
# 79.十九大报告指出，要加强和创新社会治理，打造()的社会治理格局。
# A文明和谐B共建共享C共创共治共有D共建共治共享
#
# 80.全面推进依法治国必须全面贯彻和坚持的基本原则包括()。
# A坚持从人民需求出发
# B坚持政府的领导
# C坚持中国共产党的主体地位
# D坚持依法治国和以德治国相结合
#
# 81.下列选项中，关于奏唱国歌的场合，正确的是()。
# A宪法颁布仪式
# B国家公祭仪式
# C重大社交活动
# D各级机构组织的重大纪念仪式
#
# 82.《港区国安法》规定，对分裂国家、破坏国家统一行为的首要分子或者罪行重大的，处()。
# A无期徒刑或者15年以上有期徒刑
# B无期徒刑或者10年以上有期徒刑
# C3年以上10年以下有期徒刑
# D3年以上15年以下有期徒刑
#
# 83.《中华人民共和国香港特别行政区维护国家安全法》规定，香港特别行政区行政长官应
# 当就香港特别行政区履行维护国家安全职责的情况()。
# A提交月度报告
# B提交季度报告
# C提交年度报告
# D随时提交报告
#
# 84.《港区国安法》规定，国家安全犯罪案件检控部门的检控官由律政司长征得()同意后任
# 命。
# A香港特别行政区维护国家安全委员会
# B香港特别行政区行政长官
# C香港特区维护国家安全公署
# D律政司
#
# 85.到()，旅游基础设施和公共服务设施进一步完善，乡村旅游服务质量和水平全面提升，
# 富农惠农作用更加凸显，基本形成布局合理、类型多样、功能完善、特色突出的乡村旅游发
# 展格局。
# A2021年B2022年C2025年D2035年
#
# 86.2020年11月10日，习近平在上海合作组织成员国元首理事会第二十次会议上的讲话中指
# 出，促进民心相通，构建人文共同体。文明没有优劣之分，只有()之别。
# A地域B民族C高下D特色
#
# 87.世界公认的第一次商业性旅游活动的是()。
# A莱斯特到拉夫巴勒的禁酒大会
# B利物浦之行
# C苏格兰之行
# D旅游团访问纽约
#
# 88.国务院颁发的《导游人员管理条例》标志着()。
# A每年举办一次全国导游人员资格考试有了法律依据
# B我国有了第一部旅游方面的法律
# C导游进人自由职业阶段
# D标志着我国导游队伍的建设和管理被纳入法律体系
#
# 89.团结协作、顾全大局是()在导游工作中的具体体现。
# A处理人际关系和国际交往中的行为准则
# B集体主义原则
# C处理与游客关系行为准则
# D必须遵守的一项基本道德规范
#
# 90.导游服务的扩散作用主要表现为()。
# A它是旅游接待服务的核心和纽带
# B它是衡量旅游服务质量高低的最敏感的标志
# C它同游客交往和接触的时间最长，对旅游产品方面的意见和需求最了解
# D它能对旅游目的地的旅游产品和旅行社形象起到传播作用
#
# 91.()是人们着装的总原则。
# A三色原则B三一原则CT PO原则D5W原则
#
# 92.()一般为旅行社的正式职员。
# A中级导游B外语导游C专职导游D全陪
#
# 93.()在导游工作团队中处于中心地位，起着主导作用。
# A全陪B领队C地陪D团长
#
# 94.导游人员的站姿要给游客一种O的感觉。
# A温文尔雅
#
# B悠然自得
# C谦恭有礼
# D轻盈稳健
#
# 95.对于重点团队来说，地陪与领队商量日程的一般在()。
# A到达饭店后商定
# B接机后立即商定
# C领队的房间
# D首次沿途导游过程中
#
# 96.下列仪容、仪表方面的准备，不符合导游的身份要求的是()。
# A如果有会见、宴会、舞会时，地陪要准备好适合的正装
# B夏天很热，容易流汗，为避免脱妆，导游应该适当画浓妆
# C男性导游工作时应做到前发不覆额，鬓角不近耳，后发不及领
# D导游佩戴首饰适度
#
# 97.下列内容中，属于地陪导游送行前的工作内容是()。
# A核实交通票据
# B集中交运行李
# C办理退房手续
# D致欢迎词
#
# 98.地陪进行购物服务时要严格按照《旅游法》规定来操作，以下符合规定的是()。
# A适合做好商品促销，适当增加购物次数
# B不愿参加购物活动的旅游者，自行处理，自由活动
# C地陪应向全团介绍本地商品的特色及有关商品知识
# D严格按照旅行社规定收取商家给予的购物“佣金”
#
# 99.在旅游过程中，走在旅游团队后面的是()。
# A地陪B景区讲解员C团长D全陪
#
# 100.引导游客在海外购物时，应该遵守的规则有()。
# A如果想要购买食品，要先试吃
# B对于愿意购物的游客，应该适当延长购物时间，满足他们的要求
# Ｃ不能讲价，我们应该遵守诚信经营、理性消费的原则
# D应提醒旅游者尊重购物场所购物数量限制
#
# 101.下列关于散客导游现场讲解的说法中，正确的有()。
# A导游人员应对景点的历史背景、特色等进行讲解，语言要生动，有声有色
# Ｂ单个散客，导游人员宜采取陈述的方式进行讲解
# C游览前，应按照导游提供游览路线进行旅游
# D景点游览结束后，游客自行打车回到下榻饭店，导游无需接送
#
# 102.当游客观看景区演出时，景区讲解员的服务存在问题的是()。
# A如实向游客介绍本景区演出的节目内容与特色
# B在游客观看节目过程中，讲解员可以自行离场
# C按时组织旅游者入场，倡导游客文明观看节目
# D不得强迫或变相强迫游客增加需要另行付费的演出项目
#
# 103.导游对散客提供送站服务的做法正确的一项是
# A如客人未在饭店，导游联系不上散客旅游者，要立即去送下一批客人
# B导游必须提前30分钟抵达散客旅游者下榻饭店
# C途中如果遭遇严重交通堵塞，导游要立即通知下面等候的客人
# D散客旅游者乘国际航班离站应提前2小时抵达机场
#
# 104.“玉龙雪山在碧蓝天幕的映衬下，像一条银色的玉龙在永恒地飞舞，故名玉龙山”这句
# 话所采用的修辞方法是()。
# A示现B引用C映衬Ｄ比喻
#
# 105.“长江的长度仅次于非洲的尼罗河和南美洲的亚马逊河，是世界第三长河，但是它是中
# 国第一长河”这段描述，采用了导游讲解逻辑方中的()。
# A综合法B分析法C归纳法Ｄ比较法
#
# 106.视线向下接触表示()。
# A宽容或轻视B理性或平等C期待或盼望D坦诚或自信
#
# 107.在进解杭州西湖孤山时，导游说“孤山不孤、断桥不断、长桥不长”这是运用了()的
# 形式逻辑。
# A演绎律B矛盾律C同一律D排中律
#
# 108.西岳华山虽不是五岳之首，但在五岳中却独具特色。华山是五岳中海拔最高的山峰，其
# 主峰南峰落雁峰海拔2154.9米。这段话导游采取了()进行的讲解。
# A妙用数字法B突出重点法C类比法D画龙点睛法
#
# 109.“先藏后露、欲扬先抑、引而不发”的手法是运用了导游讲解中的()。
# A突出重点法B制造悬念法C虚实结合法D秒用数字法
#
# 110.湖北通山九宫山喷雪崖，崖顶之云中湖水喷薄而出，色白如雪，如同白雪公主，蔚为壮
# 观，这是使用了()在激发游客游兴。
# A通过直观形象激发
# B运用语言艺术激发
# C通过组织文娱活动激发
# D使用声像导游手段激发
#
# 111.旅游团在游鄱阳湖时，一游客提出单独划小船游湖的要求，导游员()。
# A.不能允许其一个人去，可以找几个团友一起去
# B.婉言劝阻，若游客坚持，就不必阻拦
# C.不能答应
# D.请领队带领客人前去
#
# 112.针对游客换餐的要求，导游人员首先应()。
# A婉言拒绝，让其自行处理
# B看是否有充足的时间换餐
# C与餐厅联系，按有关规定办理
# D向游客讲清如能换妥，差价自付
#
# 113.一旦发生食物中毒，导游操作正确的是()。
# A对中毒不久而无明显呕吐者，可用手指、筷子等刺激其舌根部催吐
# B首先应立即让游客大量喝水，同时拨打“120”急救电话
# C在发生食物中毒后，立即扔掉食物样本，避免类似事件发生
# D如在呕吐物中发现血性液体，要继续催吐
#
# 114.下列造成导游人员漏接的原因中，属于主观原因的是()。
# A接待社已经变更，但是没有通知地陪
# B司机举牌接站位置不对
# C导游迟到
# D交通堵塞，没有按时抵达
#
# 115.海啸发生不幸落水时，游客应该()。
# A要尽量远离大的漂浮物，注意避免与其他硬物碰撞
# B如果口渴可以少量喝海水，但是海水能解渴
#
# C在水中不要举手，也不要乱挣扎，应尽量减少动作
# D海水温度偏低，迅速脱掉衣服
#
# 116.来华外国游客丢失行李处理方式正确的是()。
# A嘱咐失主自行到机场失物登记处办理行李丢失和认领手续
# B离开本地前行李还没有找到，导游应助失主将相关信息转告有关航空公司
# C导游要出钱为失主购置必要的生活用品
# D如行李确系丢失，导游可向有关航空公司索赔或按国际惯例取得赔偿
#
# 117.游客在自由活动时走失，导游做法正确的一项是()。
# A导游要立即亲自去寻找
# B找到走失者，问清情况，并对其严肃批评
# C应该请游客提交书面材料，证明此事旅行社无责任
# D旅游者走失后出现其他情况，应视具体情况作为治安事故或其他事故处理
#
# 118.刘女士在出国旅游期间，将护照丢失，导游应该()。
# A请组团社开具遗失证明
# B到当地警察机构报案，并取得警察机构开具的报案办理挂失证明
# C回国后，到外国驻我国使领馆补签签证
# D到我国驻该国使、领馆领取中华人民共和国旅行证
#
# 119.下列物品中，可以出境的物品是()。
# A各种武器B激光视盘C伪造的货币D带有病菌的动植物
#
# 120.旅客出入境时属于安全检查内容的是()。
# A出境登记卡
# B超限额物品
# C检查旅客是否携带爆炸物
# D国际预防接种证书
#
# 121.下列物品中关于我国民航规定可以作为行李托运的是()。
# A铁头登山杖
# B两张旅行支票
# C青花瓷瓷器
# D一坛腐乳
#
# 122.持儿童票的旅客，乘坐飞机公务舱的免费行李额是()千克。
# A10B20C30D40
#
# 123.关于旅客乘火车赴香港、西藏的要求，描述错误的是()。
# A乘火车赴西藏须先行阅读火车站公布的“高原旅行提示”
# B外国人、台湾同胞购买赴藏火车票，出示西藏自治区外事办公室或文化和旅游部门、商务
# 厅的批准函
# C乘火车赴香港须持有效证件与有效车票提前120分钟到出入境联检大厅办理验关手续
# D上车去往西藏时，须同时出示车票和填写完整的“旅客健康登记卡”
#
# 124.发生旅游意外事故以后，旅游者操作有误的是()。
# A及时向投保的保险公司报案
# B收集证据，并妥善保存
# C救治医院出具书面转院报告即可转院
# D在旅游意外保险的发生之日起180日内索赔
#
# 125.()是游客泡温泉应该遵守的规则。
# A癌症、白血病患者体征比较稳定的情况下，可以泡温泉
# B高血压和心脑血管疾病患者严禁泡温
# C空腹或太饱时不宜人浴
# Ｄ入水时，应从高温到低温，逐次浸泡，每次15~20分钟即可
#
# 126.中国最南端的曾母暗沙距离中国最北点神州北极5500公里，折合成英美制的英里大约是
# ()。
# A约3417英里B约3648英里C约3283英里D约3314海里
#
# 127.关于货币知识，叙述正确的O。
# A境外旅游者在兑换人民币的时候需要填写“外汇兑换水单”
# B旅游者一年内离境，可持护照和水单未花完的人民币兑换成外币
# C在中国境内，朝鲜元可以直接兑换成人民币
# D国际货币基金组织(SDR) 已经将人民币纳入IWF， 权重规定为10.92%
#
# 128.()与中国北京一个时区。
# A悉尼B纽约C开罗D吉隆坡
#
# 129.下列选项中，不是旅游事故特点的是()。
# A紧急性
# B危害性
# C复杂性
# D突发性
#
# 130.导游在服装搭配时可以选取()这三种安全颜色，它们最容易与其他颜色的服装搭配并
# 取得好的效果。
# A灰、黑、白
# B红、绿、蓝
# C白、红、灰
# D黑、黄、蓝
#
# 131.下列中国公民，()享有选举权的情况。
# A刘某，刚满16周岁，以自己的收入作为生活来源
# B李某，被剥夺政治权利期间
# C方某，41岁，被判刑罚服刑中
# D邓某，20岁，完全不能辨认自己行为精神病人
# E王某，38岁，虔诚的基督教徒
#
# 132.宪法的基本原则包括()。
# A法治原则
# B平等原则
# C人民主权原则
# D权利制约原则
# E基本人权原则
#
# 133.《宪法》规定，公民在(的情况下，有从国家和社会获得物质帮助的权利。
# A年老
# B年幼
# C疾病
# D丧失劳动能力
# E退休
#
# 134.《旅游法》规定，旅游者购买、接受旅游服务时，应当履行的义务包括)。
# A如实告知个人健康信息
# B不得损害他人合法权益
# C遵守旅游活动中的安全警示
# D保障旅游经营者的合法权益
# E文明旅游
#
# 135.旅游主管部门依照规定实施监督检查，可以对涉嫌违法的合同、票据、账簿以及其他资
# 料进行()。
# A查阅B封存C复制D扣押E销毁
#
# 136.旅游合同签订后，因目的地入境政策临时变更，导致某国际旅行社的出境旅游团无法成
# 行，对此()。
# A旅行社应当承担违约责任，赔偿旅游者的各项损失
# B旅行社不承担违约责任
# Ｃ旅行社无权解除合同
# Ｄ旅游者有权解除合同
# E如果合同解除，组团社应该在扣除已向履行辅助人支付且不可退还的费用后，将余款退还
# 给旅游者
#
# 137.根据《旅游法》规定，旅行社应当告知旅游者的事项包括()。
# A旅游者不适合参加旅游活动的情形
# B旅游活动中的安全注意事项
# C旅行社依法可以减免责任的信息
# D依照中国法律旅游者不宜参加的活动
# E旅游活动中旅游者的权利
#
# 138.根据《民法典》的规定，提供格式条款一方()的相应条款无效。
# A不合理的减轻其责任
# B加重对方责任
# Ｃ排除对方主要权利
# D未对格式条款予以解释
# E不合理的免除其责任
#
# 139.根据《民法典》的规定，以下关于机动车交通事故责任的说法中，正确的是()。
# A非营运机动车发生交通事故造成无偿搭乘人损害，属于该机动车一方责任的，应当免除其
# 赔偿责任
# B因租赁机动车发生交通事故造成损害属于该机动车一方责任的，由机动车使用人承担赔偿
# 责任
# C盗窃、抢劫的机动车发生交通事故造成损害的，由保险公司在机动车强制保险责任限额范
# 围内先行赔偿，有权向机动车所有人追偿
# D机动车驾驶人发生交通事故后逃逸，该机动车参加强制保险的，由保险公司在机动车强制
# 保险责任限额范围内予以赔偿
# E机动车不明，需要支付被侵权人人身伤亡的抢救、丧葬等费用的，由道路交通事故社会救
# 助基金支付
#
# 140.根据《旅行社条例》规定，以下关于旅行社质量保证金的相关规定，正确的是()。
# A旅行社存入质量保证金时，应当谨慎选择具有相应资质的银行
# B账户存期届满前三个工作日，旅行社当办理续存手续或者提交银行担保
# C质量保证金在交存期间产生的利息归旅行社所有
# Ｄ质量保证金的利息不属于保证金范畴
# E质量保证金只能以现金的形式交纳
#
# 141.依据《导游管理办法》，以下关于导游“经常执业地区”的说法正确的是()。
# A连续执业时间在3个月内累计执业达到60日
# 迅捷PDF转换器
#
# 142.小张有志从事领队业务，根据《导游管理办法》的规定，她需要具备的条件包括()。
# A取得导游证
# B具有大专以上学历
# C具有相应的语言能力
# D具有2年以上的导游从业经历
# E与委派其从事领队业务的出境社订立劳务合同
#
# 1.取得导游证；2.具有大专以上学历；3.取得相关语言水平测试等级证书或通过外语语种导游
# 资格考试，旅行社委派的领队，应当掌握相关旅游目的地国家(地区)语言或者英语，但为赴
# 港澳台地区旅游委派的领队除外；4.具有2年以上旅行社业务经营、管理或者导游等相关从业
# 经历；5.与委派其从事领队业务的取得出境旅游业务经营许可的旅行社订立劳动合同。故本题
# 选ABCD。
# 143.根据《最高院关于审理旅游纷案件的规定》规定，以下情形中旅游经营者需要承担赔
# 偿责任的是()。
# A旅游经营者对旅游辅助服务者未尽谨慎选择义务
# B旅游经营者、旅游辅助服务者未尽到安全保障义务，造成旅游者财产损失
# C旅游经营者擅自将其旅游业务转让给其他旅游经营者，旅游者在旅游过程中遭受损害
# Ｄ旅游经营者准许他人挂靠其名下从事旅游业务，造成旅游者人身损害
# E公共交通工具延误，导致旅游合同不能按约履行
#
# 144.《食品安全法》规定，保健食品的标签、说明书应当载明的信息包括()。
# A适宜人群
# B不适宜人群
# C可以预防的疾病
# Ｄ功效成分及配方
# E标志性成分含量
#
# 145.十九大报告指出，中国特色社会主义进入新时代，意味着()。
# A近代以来久经磨难的中华民族迎来了从站起来、富起来到强起来的伟大飞跃
# B迎来了实现中华民族的伟大复兴的光前景
# C中国已经全面建成小康社会
# D中国处于社会主义初级阶段的基本国情发生变化
# E中国特色社会主义道路、理论、制度、文化不断发展，拓展了发展中国家走向现代化的途
# 径
#
# 146.《英烈法》规定，禁止歪曲、丑化、亵渎、否定英雄烈士事迹和精神。英雄烈士的()
# 受法律保护。
# A事迹B姓名C肖像D名誉E荣誉
#
# 147.《旅行社有序恢复经营疫情防控措施指南(第二版)》指出，要按照()的原则，压实企业
# 主体责任，把防控责任落实到具体部门和个人，从严做好游客招保、组织、接待等环节的疫
# 情防控工作。
# A谁组织B谁生产C谁管理D谁所有E谁负责
#
# 148.党的十八大报告中指出，社会主义核心价值观是我们党凝聚全党全社会价值共识作出的
# 重要论断，以下社会主义核心价值观的内容正确的是()。
# A富强、民主、文明、和谐是国家层面的价值目标
# B富强、民主、公正、法治是法治层面的价值目标
# C自由、平等、公正、法治是社会层面的价值取向
# D爱国、敬业、诚信、友善是个人层面的价值目标
# E爱国、敬业、诚信、友善是个人行为层面的价值准则
#
# 149.地方陪同导游人员的主要职责是()。
# A安排旅游活动
# B联络工作
# C进行导游讲解
# D维护旅游者安全
# E宣传、调研工作
#
# 150.首次沿途导游的服务内容有()。
# A致欢迎词
# B风光导游
# C介绍下榻饭店
# D宣布当日或者次日活动安排
# E调整时差
#
# 151.抵达景点途中的服务内容有(。
# A重申当日活动安排
# B途中讲解
# C活跃气氛
# D介绍游览线路
# E交代游览注意事项
#
# 152.全陪为客人提供离站服务内容有(。
#
# A提醒领队再次审核交通票据和离开时间
# B与地陪交接交通票据和行李托运单，由全陪分发给客人
# C与地陪和司机话别
# D一旦发生航班延误，妥善处理游客食宿问题
# E与下一站地接社联络，协商活动日程安排
#
# 153.导游领队引导文明旅游规范的主要内容包括()。
# A应将我国和旅游目的地国家和地区文明旅游的有关法律规范向旅游者进行提示和说明
# B应主动提醒旅游者尊重当地风俗习惯宗教禁忌
# C在工作期间应以身作则，遵纪守法，恪守职责
# D应提醒旅游者注意基本的礼仪规范，仪容整洁，遵序守时
# E应引导旅游者在旅游过程中保持良好心态，尊重他人、遵守规则
#
# 154.景区讲解员讲解导游的方法与技巧()。
# A对景区的讲解要繁简适度
# B针对不同游客的需要，因人施讲
# C在讲解过程中，应自始至终与游客在起活动
# D对历史人物或事件，应充分尊重历史的原貌
# E要安排并控制好讲解时间，以免影响游客的原有行程
#
# 155.在确认接到散客以后，导游人员应该做的工作有()。
# A主动问候旅游者
# B清点行李
# C引导上车
# D代表组团社表示欢迎
# E沿途导游讲解
#
# 156.下列内容中，属于地陪落实接待事宜的是()。
# A核对日程安排表
# Ｂ地陪应在接团前同司机商定接头的时和地点
# C落实住房及用餐
# D了解不熟悉的参观游览点
# E核实旅游团(者)离开当地的出票情况
#
# 157.作为导游人员在旅游活动的组织安排上应该做到()。
# A灵活搭配活动内容
# Ｂ引导游客理性消费
# C科学安排游客饮食
# D注意旅行服务技巧
# E掌握观景赏美方法
#
# 158.人的审美感受分为()层次。
# A悦情悦理
# B悦耳悦目
# C悦心悦意
# D悦志悦神
# E悦情悦境
#
# 159.如个别游客提出更换游览项目，导游人员正确的做法是()。
# A尽量为其更换
# B不能随意更换
# C耐心与游客解释
# D让游客与组团社联系，再与地接社协商
# E断然拒绝
#
# 160.在处理游客意见和建议时，导游应注意的要点有()。
# A耐心倾听
# B表示同情和理解
# C不盲目承诺
# D答复迅速
# E及时公布旅游者信息、处理情况及处理结果
#
# 161.游客提出个人一天不随团活动，导游人员正确的做法是()。
# A婉言谢绝
# B如果是境外游客，提供必要的帮助
# C提前说明离团期间所有费用不退
# Ｄ提醒其注意安全
# E帮忙叫出租车
#
# 162.对溺水者，岸上急救的方法有()。
# A迅速清除溺水者口、鼻中的污泥、杂草及分泌物
# B将溺水者举起，使其俯卧在救护者肩
# C进行口对口人工呼吸及心脏按压
# D将游客倒立，使水流出
# E尽快联系急救中心或送去医院
#
# 163.边防检查的内容包括()。
# A护照
# B国际预防接种证书
# C传染病
# D行李物品
# E出入境登记卡
#
# 164.下列人员中，()不允许乘坐飞机的。
# A90岁老人
# B不足14天的婴儿
# C孕期超过9个月的孕妇
# D饮酒旅客
# E受过刑事犯罪处罚的人员
#
# 165.对于特殊旅游项目安全知识解读正确的是()。
# A在高原地区最好不要饮酒
# B在沙漠一旦走散后迷失了方向，不要张，待在原地等待救援
# C滑雪服最好选用套头式，上衣要宽松，以利滑行动作
# D游客漂流中一旦落水，在救生衣的浮力作用下，迅速向岸边靠拢
# E睡眠不足、熬夜之后、营养不良状态下，可以泡温泉但是时间控制在20分钟以内
#
# 1.陈光甫开办的上海商业储蓄银行旅行部，是国内最早的由中国人开办的经营旅行社业务的
# 机构。()
#
# 2.后汉张衡创作的《四愁诗》，是我国早期五言诗的代表。()
#
# 3.随着时间的推移，最终使得文字从结绳中分离出来，于是原始的文字就出现了。()
#
# 4.《诗经》中属于地方民歌部分的是风。()
#
# 5.导游带领游客游览中国古典园林，应讲
# 究"游"与“停”相结合。“游”即引导游客顺着路、径、廊漫步，“停”即在厅、堂、亭、
# 榭等处让游客停下来细细品读、观赏。()
#
# 6.伊斯兰为阿拉伯语的音译，本意为"顺服，即顺服唯--的安拉。()
#
# 7.夏朝时期已经出现了较为成熟的夯土建筑技术，建造了规模相当大的宫室和陵墓。()
#
# 8.明代以前陶瓷釉色以青为主，明代以后则以黑瓷为大宗，为瓷器的装饰创造了物质条件。
# (
# )
#
# 9.红色旅游是把红色人文景观和绿色自然景观结合起来、把革命传统教育与促进旅游产业发
# 展结合起来的一种新型的主题旅游形式。()
#
# 10.“双面绣"最能体现蜀绣的艺术特征。()
#
# 11.在中国古代科举考试中，“连中三元是指在乡试、会试和殿试中均考取第一名。这三个第
# 一名依次称为会元、解元、状元。()
#
# 12.网师园、沧浪亭、拙政园、留园、个园均是位于苏州的著名古典园林。()
#
# 13.中国共产党第十四次全国代表大会上，首次把邓小平理论作为党的指导思想写入党章。
#
# 14.1922年7月中国共产党在上海召开第二次全国代表大会，制定了最低纲领和最高纲领。
#
# 15.党的十八届四中全会以后，我们党果断作出把党和国家工作中心转移到经济建设上来、
# 实行改革开放的历史性决策。()
#
# 16.被誉为“中国天眼的500米口径球面射电望远镜，由我国天文学家南仁东于1994年提出
# 的构想，历时22年建成，于2016年9月25日落成启用。()
#
# 17.在线旅游的英文简称为OTA。()
#
# 18.国家智慧旅游公共服务网络和平台的网址是12301.cn。()一
#
# 19.距今约70万~20万年前的元谋人已经学会使用打制石器和天然火。0
#
# 20.战国时期，因多年的兼并战争形成了韩、赵、魏、楚、燕、齐、秦七雄争霸的格局。()
#
# 21.平遥古城城内街道、集市、楼房、商店等均保留原有形制，是研究明代县城建置实物资
# 料的古城。()
#
# 22.福建龙岩沉缸酒的酿法集我国黄酒酿造的各种传统精湛技术于一一身。0
#
# 22.5%~25%。龙岩沉缸酒的酿法集我国黄酒酿造的各项传统精湛技术于一身。
# 23.西湖龙井有“色绿，香郁，味醇，形美”四绝之说。0
#
# 24.现代最著名的“瓷都”是江西景德镇。()
#
# 25.宋代定窑专为宫廷烧制御用青瓷器，烧造工艺达到了中国陶瓷史上的极致。0
#
# 26.中国风筝的技艺概况起来只有四个字：扎、糊、绘、放。()
#
# 27.宣纸有“纸寿千年”的美誉。()
#
# 28.乐山大佛为弥勒佛坐像，是我国也是世界上最大的石刻佛像。
#
# 29.云冈石窟是世界现存规模最宏大的佛教艺术宝库。()
#
# 30.基督教发展史上的第二次分裂主要由宗教改革而引发。()
#
# 31.从全国范围来看，中国各民族的分布呈现以汉族为主体的大杂居、小聚居和交错居住的
# 格局。
#
# 32.北京雍和宫是世界上最大的四合院。()
#
# 33.山西平遥古城既是世界遗产又是国家5A级风景名胜区。
#
# 34.《蒙古秘史》原文本早已失传，它的汉文音译本却被编入《永乐大典》完整地保存下来。
# )
#
# 35.中国位置最北、纬度最高的省份是内蒙古自治区。()
#
# 36.安徽回族主要分布在肥东县完牌坊-一带，以"完颜”为姓。()
#
# 37.少林武功起源于河南嵩山少林寺，是中国武术体系中最庞大的门派，已成为中华武术的
# 象征。()
#
# 38.东汉京师长安城是中国历史上第一个大规模的城市，当时世界上只有欧洲的罗马城可以
# 与之媲美。()
#
# 39.柴达木盆地以“聚宝盆”著称于世。()
#
# 40.宁夏是枸杞的原产地，是世界上品质最好、种植时间最长的地方，其中又以固原所产为
# 最佳。()
#
# 41.1928年12月，()在东北易帜，中国实现了形式上的统一。
# A.阎锡山
# B.冯玉祥
# C.张学良
# D.汪精卫
#
# 42.中国共产党诞生于()，这是中国历史上开天辟地的大事。
# A.1919年
# B.1921年
# C.1927年
# D.1949年
#
# 43.1935年12月27日，毛泽东根据瓦窑堡会议决议精神，在党的活动分子会议上做了()
# 的报告。
# A.《论联合政府》
# B.《论解放区战场》
# C.《关于修改党章的报告》
# D.《论反对日本帝国主义的策略》
#
# 44.遵义会议是中共历史上一个生死攸关的转折点，开始确立了以毛泽东同志为主要代表的
# 马克思主义正确路线在党中央的领导地位，开始形成以毛泽东同志为核心的党的第一代中央
# 领导集体，这是党和革命事业转危为安、不断打开新局面最重要的保证，这次会议于()年
# 召开的。
# A.1932B.1933C.1934D.1935
#
# 45.2018年5月21日，我国发射首颗月球信号中继卫星()
# A.天兔B.玉兔C.嫦娥D.鹊桥
#
# 46.提出到2020年要将我国旅游业建设成国民经济的战略性支柱产业和人民群众更加满意的
# 现代服务业的文件是()。
# A.国务院批准发布的《国民旅游休闲纲要》
# B.国务院发布的《关于促进旅游业改革发展的若干意见》
# C.国务院发布的《关于加快发展旅游业的意见》
# D.国务院发布的《“十三五"旅游业发展规划》
#
# 47.唐朝传奇小说《柳毅传》的作者是()。
# A.陈鸿B.孟浩然C.李贺D.李朝威
#
# 48.马致远的代表作是()。
# A.《倩女离魂》B《汉宫秋》C.《墙头马上》D《西厢记》
#
# 49.被称为“书圣”的晋代著名书法家是()。
# A.蔡襄B.颜真卿C.王献之D.王羲之
#
# 50.(
# A.孔子
#
# 51.五言诗形成的朝代是()。
# A.秦朝B.汉朝C.隋朝D唐朝
#
# 52.“开辟荆榛，千秋功业；驱除荷虏，一代英雄。”是郭若沫赞颂()的楹联。
# A.郑成功B康有为C.岳飞D文天祥
#
# 53.中国近现当代文学知识，重要文化名人及作品的说法正确的有()。
# A.当代文学是指1917年~1949年间在中国产生的文学现象和文学创作的总和
# B.1949年7月召开的中华全国文学艺术工作者大会，一般被文学史家们称为是“现代文学
# 的伟大开端”
# C.鲁迅的《呐喊》被视为中国文学史上现代白话小说的开山之作
# D.近代文学指1840年鸦片战争至1919年"五四运动"前夕的文学
#
# 54."山穷水复疑无路，柳暗花明又-村"常被导游引用，其原作者是()。
# A.陆游B.李贺C.杜甫D.李白
#
# 55.素有"欧洲最有气势的城市”之称的英国城市是
# A.伦敦B.诺丁汉C.利物浦D.爱丁堡
#
# 56.欧洲最大的海港是()，它也是荷兰第二大城市。
# A.海牙B.莱顿城C.鹿特丹D.阿姆斯特丹
#
# 57.金字塔在埃及共发现()座，其中最有名的是胡夫金字塔和狮身人面像。
# A.106B.96C.86D.76
#
# 58.()守时观念较差，赴约常常迟到。
# A意大利人B.俄罗斯人C.法国人D.德国人
#
# 59.中国古典园林入口处常构筑假山进行遮挡，这种构景手法就称为()。
# A.抑景B.漏景C.障景D.借景
#
# 60.下列园林中属于江南类型的是()。
# A.颐和园B.寄畅园C.清晖园D.可园
#
# 61.中国古典园林里最适宜观赏水景的建筑是()。
# A.台B.轩C.榭D.舫
#
# 62.现代园林设计面向的是()。
# A.游客B.城市居民C.大众D.工人
#
# 63.享有“瓷国明珠”美誉的是(。
# A.唐三彩B.釉下彩瓷C.青花瓷D.龙泉青瓷
#
# 64.元明清时期，()进入宫廷并成为御膳支柱。
# A.陕西菜B.山东菜C.河南菜D.河北菜
#
# 65.中国第一、世界第三长河长江，发源于青藏高原()主峰。
# A.唐古拉山
# B.阿勒泰山
# C.巴颜喀拉山
# D.喀喇昆仑山
#
# 66.我国第一部针灸学专著《针灸甲乙经》的作者是()。
#
# A.王叔和
# B.皇甫谧
# C.王惟一
# D.张从政
#
# 67.我国现存最完备的农书《齐民要术》的作者是()。
# A.王祯B.许光启C.贾思勰D.宋应星
#
# 68.提出“民贵君轻”思想主张的是战国时期的思想家()。
# A.孟子B.孔子C.墨子D.荀子
#
# 69.世界旅游日是每年的()，由世界旅游组织确定的旅游工作者和旅游者的节日。
# A.10月27日B.9月27日C.8月27日D.7月27日
#
# 70.()是我国第一大内陆湖泊，也是我国最大的咸水湖。
# A.青海湖B.洞庭湖C.镜泊湖D.鄱阳湖
#
# 71.世界上最早的、由国家颁布的药典是()。
# A.《四部医典》B.《唐本草》C.《千金方》D.《本草纲目》
#
# 72.元代的《授时历》中-年的周期与现行公历基本相同，但问世比现行公历早300年，其发
# 明者是()。
# A僧一行B.沈括C.郭守敬D.落下闳
#
# 73.按茶叶初加工方式分类，安溪铁观音属于()。
# A.青茶B.黑茶C.红茶D.绿茶
#
# 74.中国四大名砚中，产于广东省肇庆市的是()。
# A.歙砚B.端砚C.洮河砚D.澄泥砚
#
# 75.河姆渡遗址中最重要的是发现()。
# A.稻种B.玉琮C.黑陶D.彩陶
#
# 76.北京天坛由五组建筑组成，其中用于祭天的建筑是()。
# A.圜丘坛B.祈年殿C.皇穹宇D.斋宫
#
# 77.佛教四大名山中，文殊菩萨道场在()。
# A.九华山B.普陀山C.峨眉山D.五台山
#
# 78.1945年，中华民族经历(
# A.8年
#
# 79.全国各地以鸡为原料的菜中有很多名菜，如叫花鸡、太爷鸡、德州扒鸡，上述三道菜所
# 属的菜系依次是()。
# A川菜、粤菜、鲁菜
# B苏菜、鲁菜、川菜
# C苏菜、粤菜、鲁菜
# D鲁菜、徽菜、川菜
#
# 80.中国是世界上第()个有原子弹的国家。
# A.三B.四C.五D.六
#
# 81.古代丝绸之路的开拓者是()。
# A唐代的玄奘
# B明代的郑和
# C西汉的司马迁
# D西汉的张骞
#
# 82.()以彩池、雪山、峡谷、森林“四绝”著称于世，有着“圣地仙境，人间瑶池”的美誉。
# A九寨沟B黄龙C武陵源D武夷山
#
# 83.有“陕西故宫"之称的庙宇是()。
# A中岳庙
# B岱庙
# C南岳庙
# D西岳庙
#
# 84.佛光是大气中的()现象所构成的奇幻景观。
# A.全反射B.衍射C.折射D.透射
#
# 85.被誉为“金镶玉”的中国名茶是()。
# A西湖龙井B黄山毛峰C君山银针D安吉白茶
#
# 86.中浓度啤酒的原麦汁浓度为()。
# A.24°~28°B.14°~20°C.10°~12°D.6°~8°
#
# 3.1%~3.8%)和高浓度啤酒(14°~20°，4.9%~5.6%)
# 87.以镶嵌螺钿最具特色的漆器是()。
# A北京雕漆
# B福州脱胎漆器
# C平遥推光漆器
# D扬州镶嵌漆器
#
# 88.()爱穿白衣素服，因而有“白衣民族”之称。
# A.白族B.朝鲜族C.维吾尔族D.藏族
#
# 89.彝族最盛大的传统节日是()。
# A.火把节B.三月三C.密枝节D.三朵节
#
# 90.用蜡染花布做成的“巴迪”服是()的国服。
# A.泰国
# B.菲律宾
# C.马来西亚
# D.印度尼西亚
#
# 91.印度尼西亚唯一信奉印度教的地区，有“千庙之岛"之誉称的是()。
# A.巴厘岛B.雅加达C.婆罗浮屠D.万隆
#
# 92.沈阳故宫按照建筑布局和建造时间分为东、中、西三路，三路上的建筑依次是()。
# A凤凰楼，文溯阁，十王亭
# B十王亭，文溯阁，凤凰楼
# C凤凰楼，十王亭，文溯阁
# D十王亭，凤凰楼，文溯阁
#
# 93.中国现存古城中，(
# A丽江古城
#
# 94.用于识别、区分氏族，实行族外婚，即其作用是“别婚姻”的是()。
# A名B姓C氏D字
#
# 95.中国古代帝王在天坛祭天的时间是()。
# A冬至B秋分C夏至D春分
#
# 96.下列道教宫观中，享有"道观之祖”美誉的是()。
# A陕西周至草楼观
# B北京白云观
# C四川青城山常道观
# D陕西户县重阳宫
#
# 97.“江作青罗带，山如碧玉簪”是桂林山水的最佳写照，其作者是()
# A.李白B.白居易C.韩愈D.欧阳修
#
# 98.在中国的农历二十四节气中，在清明与立夏之间的节气是()。
# A.惊蛰B.小满C.谷雨D.芒种
#
# 99.()屋顶为四坡盔顶，屋面上凸下凹，为中国现存最大盔顶建筑。
# A岳阳岳阳楼
# B武汉黄鹤楼
# C宁波天一阁
# D南昌滕王阁
#
# 100.1935年12月召开的中共中央瓦窑堡会议，明确提出党的基本策略是()。
# A.建立国共合作统一战线
# B.武装反抗国民党反动派
# C.建立广泛的抗日民族统一战线
# D.在军队中建立党的组织和党代表制度
#
# 101.下列关于宋代名篇《赤壁赋》的说法中错误的是()
# A.作者苏轼字子瞻，号东坡居士，是四川眉山人
# B.文章开头写作者与客人秋夜泛舟的情景和飘飘欲仙的心境
# C.该篇成为六朝骈赋和唐代律赋之后出现的新体散文赋的最佳之作
# D.文中“逝者如斯”指人的离开与过世是无常的
#
# 102.我国拥有帝王宫殿、庙坛和陵墓数量最多、内容最丰富的城市是()。
# A.南京B.北京C.西安D.洛阳
#
# 103.天津杨柳青年画产生于()年间。
# A.清康熙B.清乾隆C.明成化D.明崇祯
#
# 104.河北省建有国家()风电示范基地--坝上地区百万千瓦级风电基地。
# A.第一个B.第二个C.第三个D.第四个
#
# 105.我国北方地区最好的深水不冻港是()。
# A.营口港B.丹东港C.锦州港D.大连港
#
# 106.吉林省是国家“一带一路”向()开放的重要窗口。
# A.东B.西C.南D.北
#
# 107.中国地势最低的省是()。
# A.安徽省B.广东省C.江苏省D.福建省
#
# 108.畲族的()曾被列为贡品，1915年获巴拿马万国博览会金质奖章。
# A.擂茶B.惠明茶C.龙井茶D.茉莉花茶
#
# 109.被周恩来总理赞誉的“四特酒”出自江西()。
# A.九江B.萍乡C.瑞金D.樟树
#
# 111.下列关于作者与作品的组合中，正确的是()。
# A.贾谊一《三都赋》
# Ｂ.左思一《吊屈原赋》
# C.钟峡一《衡山记》
# D.干宝--《搜神记》
#
# 112.珍贵文物《清明上河图》现存于()。
# A.北京故宫博物院B.台北故宫博物院C.中国历史博物馆D.河南省博物馆
#
# 113.湖北的梅雨期是()。
# A.5月上旬至6月上旬
# B.5月中旬至6月中旬
# C.6月上旬至7月上旬
# D6月中旬至7月中旬
#
# 114.湖南又称“三湘四水”，指湘江先后与三条河流相汇，其中人洞庭湖时与之与相汇的河
# 流是()。
# A.沅水B.潇水C.蒸水D.澧水
#
# 115.有“南国红豆”之誉的是()。
# A.人龙舞B.粤剧C.岭南园林D.广东音乐
#
# 116.有“东海一绝”之誉的是()。
# A.人龙舞B.南狮C.闹军坡D.赛龙舟
#
# 117.海南“海产八珍”之首是()。
# A.鲍鱼B.龙虾C.扇贝D.海参
#
# 118.重庆市有“生物基因库”“中华药库”之称的是()。
# A.金佛山B.四面山C.缙云山D.仙女山
#
# 119.重庆成为直辖市的时间是()。
# A.1995年B.1996年C.1997年D.1999年
#
# 120.()被誉为“有色金属王国”。
# A.贵州省B.辽宁省C.海南省D.云南省
#
# 121.云南初步形成通往东南亚、南亚国家的三条便捷的国际大通道，其中东路通道是通往()。
# A.缅甸B.越南C.老挝D.泰国
#
# 12.被誉为“天路”的青藏铁路于(
# A.2012年B.2013年
#
# 123.1963年发现的“蓝田猿人”，是全国发现的时间最早、最为完整的猿人头盖骨化石，出
# 土于()。
# A.甘肃B.山西C.河北D.陕西
#
# 124.()境内保存的长城总计超过3600千米，占全国现存总量的60%以上。
# A.天津B.山西C.河北D.甘肃
#
# 125.()伏羲庙是我国目前规模最宏大、保存最完整的纪念伏羲氏的明代建筑群，是历代官
# 方祭祀伏羲的重要地方。
# A.兰州B.天水C.酒泉D.陇南
#
# 126.()在中华民族的文化史上具有“万山之祖”的显赫地位，古人称其为“中华龙脉之祖”
# A天山
# B祁连山
# C昆仑山
# D唐古拉山
#
# 127.西部唯一的国家葡萄酒原产地保护区玉泉葡萄庄园在()。
# A.新疆B.宁夏C.青海D.山西
#
# 128.唐玄奘西行取经途中，曾欣赏过()，并发出赞叹“管弦伎乐，特善诸国!"。
# A.达瓦孜B.高昌乐舞C.龟拉乐舞D.疏勒乐舞
#
# 129.台湾第一大港是()。
# A.台中港B.基隆港C.高雄港D.安平港
#
# 130.广东的世界遗产除了“开平碉楼与古村落"外，还有一项是()。
# A.肇庆星湖B.客家大围屋C.岭南园林D.韶关丹霞山
#
# 131.朱元璋建立明朝后，通过()等措施，极大地强化了中央集权的封建君主专制。
# A.废除丞相
# B.实行郡县制度
# C.建立厂卫特务机构
# D.以八股取士
# E.在地方设三司
#
# 132.隋朝创立的()为以后各朝代沿袭、改进。
# A.中央集权制
# B.三省六部制
# C.科举制
# D.分封制
# E.行省制度
#
# 133.东晋时的顾恺之专擅人物画，在我国绘画史上他第一个明确提出“以形写神”的主张，
# 其代表作有()。
# A.《女史箴图》
# B.《龙凤人物图》
# C.《步辇图》
# D.《历代帝王图卷》
# E.《洛神赋图》
#
# 134.我国四大古建筑群包括()。
# A泰山岱庙
# B曲阜“三孔”
# C承德避暑山庄
# D北京故宫
# E登封少林寺
#
# 135.我国信仰上座部佛教的少数民族有()。
# A.蒙古族B.布朗族教的少民族有(D.白族E傣族C.族
#
# 136.中国书法史上以草书著称的书法家有()。
# A.颜真卿B.王羲之C.张旭D.柳公权E.张芝
#
# 137.下列文化名人中，属于儒家代表人物的有()。
# A.程颢B.朱熹C.董仲舒D.王阳明E.韩非
#
# 138.下列关于道教全真道特点说法中，正确的是()。
# A.以修身养性为正道
# B.可以有家室，可不出家，不住宫观
# C.道士须出家住宫观，不得蓄妻室
# D.不重内丹修炼，不尚符篆
# E.主张道、佛、儒三教合一
#
# 139.下列关于中国古塔的说法中，正确的有()。
# A.应县木塔是楼阁式塔
# B.密檐式塔一般可以登临
# C.北京真觉寺塔是现存年代最早、规模最大的覆钵式塔
# D.金刚宝座塔最早的实物始建于唐代
# E.楼阁式塔历史最久，形式也最为壮观
#
# 140.下列关于青藏铁路工程的描述正确的是()。
# A.是世界上海拔最高的高原铁路
# B.是通往西藏腹地的第一条铁路
# C.是世界上线路最长的高原铁路
# D.被国外媒体评为“是有史以来最困难的铁路工程项目”
# E.2016年7月1日，青藏铁路全线通车
#
# 141.下列对遵义会议的描述中，正确的是()。
# A.会议集中解决了具有决定意义的军事和组织问题
# B.会议增选毛泽东为中央政治局常委
# C.会后决定由叶挺代替博古负中央总的责
# D.遵义会议是中共历史上一个生死攸关的转折点
# E.遵义会议开始形成以毛泽东同志为核心的党的第一代中央领导集体
#
# 142.我国著名的荒漠景观有()。
# A.甘肃张掖
# B.台湾野柳
# C.甘肃鸣沙山
# D.宁夏沙坡头
# E.新疆乌尔禾
#
# 143.下列湖泊中属于“构造湖”的是()
# A.云南滇池
# B.台湾日月潭
# C.浙江千岛湖
# D.新疆喀纳斯湖
# E.长白山天池
#
# 144.下列酒中，属于黄酒的有()。
# A.绍兴加饭酒B.李子酒C.龙岩沉缸酒D.西凤酒E.三花酒
#
# 146.下列关于宋代五大名窑的说法中，正确的有()。
# A.汝窑居于五大名窑之首，因窑址位于宋时河南汝州境内而得名，被世人称为“似玉、非玉、
# 而胜玉”
# B.钧窑以“窑变”著称，素有“入窑一色、出窑万彩”“钧瓷无双”的特点
# C.定窑以烧制白瓷著称，以装饰见长
# D.哥窑瓷器以造型端庄古朴著称，其重要特征是釉面开片，俗称“金丝铁线”
# E.官窑专为宫廷烧制瓷器
#
# 147.下列属于景德镇“四大传统名瓷”的有()。
# A.青花瓷B.颜色釉瓷C.玲珑瓷D.粉彩瓷E.釉下彩瓷
#
# 148.下列选项中，历史上曾被誉为“天下第一泉”的有()。
# A.镇江中泠泉B.无锡惠山泉C.庐山谷帘泉D.济南趵突泉E.北京玉泉
#
# 149.下列现代诗人中属于追踪现代主义诗风的“象征诗派”的代表诗人是()。
# A.李金发B.穆木天C.蒋光慈D.殷夫E.闻一多
#
# 150.目前中国国内旅游市场的主要特点有()。
# A.以散客为主
# B.人均消费水平高
# C.市场规模大
# D.发展潜力足，我国已成为世界上最大的国内旅游市场
# E.旅游收入增长快，超过同期旅游人数增长速度
#
# 151.下列属于小篆代表作的有()。
# A.《泰山刻石》B.《琅琊刻石》C.《曹全碑》D.《会稽刻石》E.《衡方碑》
#
# 152.汉代的选官制度有()。
# A.世卿世禄制B.科举制C.征辟制D.察举制E.禅让制
#
# 153.下列戏剧为“中国四大古典戏剧”的是()。
# A.《汉宫秋》B.《牡丹亭》C.《西厢记》D.《窦娥冤》E.《长生殿》
#
# 154.私家园林是我国古代园林重要组成部分，它的特点是()。
# A.常用假山假水
# B.规模较小
# C.园中建筑金碧辉煌
# D.居住和游览合一
# E.专供帝王休憩享乐之用
#
# 155.河北省是中国著名的武术之乡，现存规模和影响较大的武术拳种有()。
# A.八极拳B.燕青拳C.八卦拳D.梅花拳E.形意拳
#
# 156.黑龙江省滑雪旅游资源主要集中在()四大区域。
# A.大兴安岭地区
# B.齐齐哈尔市
# C.牡丹江市
# D.伊春市
# E.哈尔滨市
#
# 157.上海()形成双龙戏珠之势，成为上海改革开放的象征。
# A.东方明珠广播电视塔
# B.金茂大厦
# C.南浦大桥
# D.杨浦大桥
# E.外滩大道
#
# 158.下列文化中，属于福建文化的是()。
# A.客家文化B.妈祖文化C.朱子文化D.海丝文化E.道教文化
#
# 159.山东影响最大的秧歌有()。
# A.鼓子秧歌B.胶州秧歌C.海阳秧歌D.高跷秧歌E.海城秧歌
#
# 160.湖南籍作家丁玲的代表作有()。
# A.《梦珂》
# B.《莎菲女士的日记》
# C.《太阳照在桑干河上》
# D.《山乡巨变》
# E.《暴风骤雨》
#
# 161.桂林三宝是指()。
# A.三花酒B.桂林辣椒酱C.桂林腐乳D.桂花糕E.桂林米粉
#
# 162.下列属于“海南四大名菜”的是()。
# A.文昌鸡B.嘉积鸭C.和乐蟹D.东山羊E.临高乳猪
#
# 163.宋置川陕路，后分置()四路总称四川路，至此始有四川之名。
# A.益B.梓C.利D.燮E.夔
#
# 164.贵州在婚丧嫁娶方面，汉族习俗和全国其他地区基本相同，少数民族风格各异，秉承着
# 自己的习俗，如()。
# A苗族的游方
# B侗族的行歌坐月
# C土家族的哭嫁
# D保安族的宴席曲
# E瑶族的凿壁谈婚
#
# 165.中国、哈萨克斯坦和吉尔吉斯斯坦三国联合申遗的世界遗产“丝绸之路：长安一天山廊道
# 的路网”，中国部分由()联合申报。
# A.甘肃省
# B.河南省
# C.宁夏自治区
# D.陕西省
# E.新疆自治区
#
#
# isExist exist
